# %%
#imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
#load dataset 
data = pd.read_csv('datasets/ny_hp_cleaned.csv')
data.head()
# Out:
#     price  lot_size  waterfront  age  land_value  new_construct  central_air  \
# 0  132500      0.09           0   42       50000              0            0
# 1  181115      0.92           0    0       22300              0            0
# 2  109000      0.19           0  133        7300              0            0
# 3  155000      0.41           0   13       18700              0            0
# 4   86060      0.11           0    0       15000              1            1
#
#   fuel_type  heat_type sewer_type  living_area  pct_college  bedrooms  \
# 0  Electric   Electric    Private          906           35         2
# 1       Gas  Hot Water    Private         1953           51         3
# 2       Gas  Hot Water     Public         1944           51         4
# 3       Gas    Hot Air    Private         1944           51         3
# 4       Gas    Hot Air     Public          840           51         2
#
#    fireplaces  bathrooms  rooms  test
# 0           1        1.0      5     0
# ...

# %%
#histogram of house prices
plt.figure(figsize=(10,6))
sns.histplot(data['price'], bins=50, kde=True)
plt.title('Distribution of House Prices in New York')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
stats.describe(data['price'])
# Out:
# DescribeResult(nobs=1728, minmax=(np.int64(5000), np.int64(775000)), mean=np.float64(211966.7054398148), variance=np.float64(9690707465.040573), skewness=np.float64(1.5763435633410208), kurtosis=np.float64(4.1759434086605935))

# %%
# Get descriptive statistics using pandas describe()
data['price'].describe()
# Out:
# count      1728.000000
# mean     211966.705440
# std       98441.391015
# min        5000.000000
# 25%      145000.000000
# 50%      189900.000000
# 75%      259000.000000
# max      775000.000000
# Name: price, dtype: float64

# %% [markdown]
# * Price is positively skewed, with a skewness of 1.5763
# * Price has a long tail, with a kurtosis of 4.1760
# * there is a mean houseprice of USD 211,996.71 and a median houseprice of USD 189, 900.00
# * Suggests that house prices in New York have heavy high end prices, dragging the mean up and over the median

# %%
#pairplot to see relationships between variables. This takes ages to run so find the plot in plots/eda
sns.pairplot(data)
#plt.savefig('plots/ny_houseprices_pairplot.png')
plt.show()

# %%
# correlation heatmap
numeric_data = data.select_dtypes(include='number')
plt.figure(figsize=(12,10))
correlation_matrix = numeric_data.corr()
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix of New York House Prices Dataset')
plt.savefig('plots/eda/correlations_heatmap.png')
plt.show()
